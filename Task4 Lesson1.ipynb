# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
k=1
while k==1:
    k=float(input('Введите значение переменной k функции cos(к*х) (k - не должно равняться 1): '))
# Out:
# Введите значение переменной k функции cos(к*х) (k - не должно равняться 1): 4

# %%
x = np.linspace(-np.pi*3, np.pi*3, 150)
plt.plot(x, np.sin(x), label = 'cos(x)')
plt.plot(x, np.sin(k*x), label = 'cos(k,x)')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.legend(loc = 'lower right')
plt.show()
